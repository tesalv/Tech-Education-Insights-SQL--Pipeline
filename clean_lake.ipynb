# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Newchapter1!",
                               db="clean_lake"))

# %%
cnx = mysql.connector.connect(user="root",
                            password="Newchapter1!",
                            host="127.0.0.1")

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()
cursor

# %%
query = """ SELECT*
FROM bootcamps.comments;"""

cursor.execute(query)

# %%
result = cursor.fetchall()
result

type(result)
# Out:
# list

# %%
clean_df = pd.DataFrame(result)
column_names = [head[0] for head in cursor.description]
clean_df.columns=column_names
clean_df.head(1)
# Out:
#    index  Unnamed: 0      id                     name  anonymous  \
# 0      0           0  293764  Ana Valeria Khatchikian          0
#
#   hostProgramName  graduatingYear  isAlumni    jobTitle tagline  ...  \
# 0            None          2022.0         0  Journalist   Great  ...
#
#                                              rawBody  createdAt   queryDate  \
# 0  <p>I really enjoyed the boot camp, it was very...  10/7/2022  2022-10-07
#
#                  program overallScore  overall  curriculum  jobSupport  \
# 0  UX/UI Design Bootcamp          3.3      4.0         3.0         3.0
#
#                                          review_body    school
# 0  I really enjoyed the boot camp, it was very in...  ironhack
#
# [1 rows x 21 columns]

# %%
clean_df=clean_df.drop(["name","hostProgramName","isAlumni","jobTitle","body","rawBody","createdAt","queryDate", "Unnamed: 0","index"],axis=1)
clean_df.head(1)
# Out:
#        id  anonymous  graduatingYear tagline                program  \
# 0  293764          0          2022.0   Great  UX/UI Design Bootcamp
#
#    overallScore  overall  curriculum  jobSupport  \
# 0           3.3      4.0         3.0         3.0
#
#                                          review_body    school
# 0  I really enjoyed the boot camp, it was very in...  ironhack

# %%
clean_df.to_sql('clean_comments', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 3680

# %%
clean_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 3     293664          0          2022.0
# 4     293621          0          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 3     High recommended Data analytics Bootcamp  (Iro...
# 4                         Fascinating and Underwhelming
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
clean_df["update_program"]=""
clean_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 3     293664          0          2022.0
# 4     293621          0          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 3     High recommended Data analytics Bootcamp  (Iro...
# 4                         Fascinating and Underwhelming
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
clean_df.isnull().sum()
# Out:
# id                  0
# anonymous           0
# graduatingYear      4
# tagline             1
# program           387
# overallScore        8
# overall            10
# curriculum         47
# jobSupport        279
# review_body         0
# school              0
# update_program      0
# dtype: int64

# %%
condition=~(clean_df["program"].isnull())
condition
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 3675     True
# 3676     True
# 3677     True
# 3678     True
# 3679     True
# Name: program, Length: 3680, dtype: bool

# %%
null_cleaned_df=clean_df[condition]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
# clean_df=pd.DataFrame([["UX/UI Design Bootcamp",""]],columns=["program","update_programs"])

# clean_df["update_programs"][clean_df["program"].str.contains("UX")]="UX/UI"
# clean_df

def program_name(s):

    if 'UI' in s or 'Digital' in s or 'Design' in s:
      
        return "UX/UI"
    elif 'Data' in s or 'Analytics' in s or 'Machine' in s:
        
        return "DATA"
    elif 'Software' in s or 'Dev' in s :
        
        return "WEBDEV"
    elif 'Cyber' in s:
         
        return "CYBER"
    else:
        return "TO DELETE"



null_cleaned_df["update_program"] = null_cleaned_df["program"].apply(program_name)
null_cleaned_df=null_cleaned_df[["id","anonymous","graduatingYear","tagline","program","overallScore","overall","curriculum","jobSupport","review_body","school","update_program"]]


display(null_cleaned_df)
# Out:
# C:\Users\te_sa\AppData\Local\Temp\ipykernel_18004\172112999.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_cleaned_df["update_program"] = null_cleaned_df["program"].apply(program_name)
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
# ...

# %%
def program_time(s):

    if 'Part' in s:
        return "Part time"
    else:
        return "Full time"   



null_cleaned_df["program_time"] = null_cleaned_df["program"].apply(program_time)
#null_cleaned_df=null_cleaned_df[["anonymous","graduatingYear","tagline","program","overallScore","overall","curriculum","jobSupport","review_body","school","update_program"]]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
def on_off_program(s):

    if 'Online' in s:
        return "Online"
    else:
        return "In Person"   


null_cleaned_df["program_presence"] = null_cleaned_df["program"].apply(on_off_program)
#null_cleaned_df=null_cleaned_df[["anonymous","graduatingYear","tagline","program","overallScore","overall","curriculum","jobSupport","review_body","school","update_program"]]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
(null_cleaned_df["program_presence"]=="Online")&(null_cleaned_df["school"]!="app-academy")
null_cleaned_df[(null_cleaned_df["program_presence"]=="Online")&(null_cleaned_df["school"]!="app-academy")]
# Out:
# Empty DataFrame
# Columns: [id, anonymous, graduatingYear, tagline, program, overallScore, overall, curriculum, jobSupport, review_body, school, update_program, program_time, program_presence]
# Index: []

# %%
## is there online words in the comments? to check if it is different than the course name

def on_off_program_from_comment(s):

    if 'Online' in s:
        return "Online"
    else:
        return "In Person"   


null_cleaned_df["program_presence_review"] = null_cleaned_df["review_body"].apply(on_off_program)
#null_cleaned_df=null_cleaned_df[["anonymous","graduatingYear","tagline","program","overallScore","overall","curriculum","jobSupport","review_body","school","update_program"]]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df[null_cleaned_df["program_presence"]=="Online"].count()
# Out:
# id                         164
# anonymous                  164
# graduatingYear             164
# tagline                    164
# program                    164
# overallScore               164
# overall                    164
# curriculum                 164
# jobSupport                 161
# review_body                164
# school                     164
# update_program             164
# program_time               164
# program_presence           164
# program_presence_review    164
# dtype: int64

# %%
null_cleaned_df[null_cleaned_df["program_presence_review"]=="Online"].count()
# Out:
# id                         19
# anonymous                  19
# graduatingYear             19
# tagline                    19
# program                    19
# overallScore               19
# overall                    19
# curriculum                 19
# jobSupport                 18
# review_body                19
# school                     19
# update_program             19
# program_time               19
# program_presence           19
# program_presence_review    19
# dtype: int64

# %%
null_cleaned_df.isnull().sum()
# Out:
# id                           0
# anonymous                    0
# graduatingYear               3
# tagline                      0
# program                      0
# overallScore                 7
# overall                      9
# curriculum                  44
# jobSupport                 240
# review_body                  0
# school                       0
# update_program               0
# program_time                 0
# program_presence             0
# program_presence_review      0
# dtype: int64

# %%
null_cleaned_df=null_cleaned_df[~null_cleaned_df["overallScore"].isnull()]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df[null_cleaned_df["program_presence_review"]=="Online"]
# Out:
#           id  anonymous  graduatingYear  \
# 1194  290167          0          2022.0
# 1196  289928          0          2022.0
# 1258  279762          0          2021.0
# 1299  275368          1          2021.0
# 1322  274143          1          2020.0
# 1380  267378          0          2020.0
# 1436  264297          0          2020.0
# 1443  263635          0          2020.0
# 1450  263386          0          2019.0
# 1636  252786          0          2019.0
# 1639  252911          0          2019.0
# 1960  243121          1          2018.0
# 2658  280775          0          2021.0
# 2728  278689          0          2021.0
# 3060  267786          1          2020.0
# 3118  265627          0          2020.0
# 3137  264845          0          2020.0
# 3139  264775          0          2020.0
# 3618  243184          0          2017.0
#
#                                                 tagline  \
# 1194  Best way to learn the skills needed and to bec...
# ...

# %%
list(null_cleaned_df["review_body"][null_cleaned_df["program_presence_review"]=="Online"])

# %%
print(null_cleaned_df["program"].nunique())
print(null_cleaned_df["program"].unique())
# Out:
# 39
# ['UX/UI Design Bootcamp' 'Data Analytics Part-Time'
#  'Cybersecurity Part-Time' 'Web Development Part-Time'
#  'Web Development Bootcamp' 'Data Analytics Bootcamp'
#  'UX/UI Design Part-Time' 'Cyber Security Bootcamp'
#  'Full-time Web Development Bootcamp' 'Full-time UX/UI Design Bootcamp'
#  'Part-time Web Development' 'Part-time UX/UI Design'
#  'Full-time Web Development Bootcamp ' 'Part-time UX/UI Design '
#  'Web Design' '24-Week Online Full-Time Software Engineering Program'
#  'Software Engineer Track: Online' 'App Academy Open'
#  'Software Engineer Track: In-Person' 'Bootcamp Prep'
#  'UI/UX Design Career Track' 'Data Analytics Career Track'
#  'Software Engineering Career Track Prep Course'
#  'Software Engineering Career Track' 'Data Science Career Track'
#  'Cyber Security Career Track' 'UX Career Track'
#  'Data Science Career Track Prep' 'Introduction to Design'
#  'Machine Learning Engineering Career Track'
# ...

# %%
null_cleaned_df["update_program"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 4       False
# 5       False
#         ...
# 3675    False
# 3676    False
# 3677    False
# 3678    False
# 3679    False
# Name: update_program, Length: 3286, dtype: bool

# %%
null_cleaned_df.shape
# Out:
# (3286, 15)

# %%
clean_df.shape
# Out:
# (3680, 12)

# %%
null_cleaned_df['update_program'].unique()
# Out:
# array(['UX/UI', 'DATA', 'CYBER', 'WEBDEV', 'TO DELETE'], dtype=object)

# %%
null_cleaned_df=null_cleaned_df[null_cleaned_df["update_program"]!="TO DELETE"]
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df["update_program"].unique()
# Out:
# array(['UX/UI', 'DATA', 'CYBER', 'WEBDEV'], dtype=object)

# %%
null_cleaned_df.describe()
# Out:
#                   id    anonymous  graduatingYear  overallScore      overall  \
# count    3063.000000  3063.000000     3061.000000   3063.000000  3061.000000
# mean   258032.062357     0.174339     2019.004574      4.654130     4.731787
# std     17739.191761     0.379463        1.817843      0.575191     0.598691
# min    231519.000000     0.000000     2011.000000      1.000000     1.000000
# 25%    242394.000000     0.000000     2018.000000      4.400000     5.000000
# 50%    258098.000000     0.000000     2019.000000      5.000000     5.000000
# 75%    272131.500000     0.000000     2020.000000      5.000000     5.000000
# max    293851.000000     1.000000     2022.000000      5.000000     5.000000
#
#         curriculum   jobSupport
# count  3026.000000  2856.000000
# mean      4.625909     4.585784
# std       0.640384     0.769603
# min       1.000000     1.000000
# 25%       4.000000     4.000000
# 50%       5.000000     5.000000
# 75%       5.000000     5.000000
# ...

# %%
ironhack_series=null_cleaned_df[null_cleaned_df["school"]=="ironhack"]
ironhack_series.describe()
# Out:
#                   id    anonymous  graduatingYear  overallScore      overall  \
# count    1050.000000  1050.000000     1050.000000   1050.000000  1050.000000
# mean   252560.134286     0.100000     2018.438095      4.780095     4.827619
# std     16160.940559     0.300143        1.675391      0.545695     0.559006
# min    231531.000000     0.000000     2011.000000      1.000000     1.000000
# 25%    239298.250000     0.000000     2017.000000      4.700000     5.000000
# 50%    245467.500000     0.000000     2018.000000      5.000000     5.000000
# 75%    263963.750000     0.000000     2020.000000      5.000000     5.000000
# max    293764.000000     1.000000     2022.000000      5.000000     5.000000
#
#         curriculum   jobSupport
# count  1019.000000  1010.000000
# mean      4.739941     4.759406
# std       0.601312     0.659260
# min       1.000000     1.000000
# 25%       5.000000     5.000000
# 50%       5.000000     5.000000
# 75%       5.000000     5.000000
# ...

# %%
springboard_series=null_cleaned_df[null_cleaned_df["school"]=="springboard"]
springboard_series.describe()
# Out:
#                   id    anonymous  graduatingYear  overallScore      overall  \
# count    1056.000000  1056.000000     1056.000000   1056.000000  1056.000000
# mean   267250.306818     0.125000     2019.928030      4.588826     4.682765
# std     16894.759537     0.330876        1.602288      0.597585     0.620905
# min    231567.000000     0.000000     2015.000000      1.000000     1.000000
# 25%    250956.500000     0.000000     2019.000000      4.300000     4.000000
# 50%    270644.000000     0.000000     2020.000000      4.700000     5.000000
# 75%    281832.250000     0.000000     2021.000000      5.000000     5.000000
# max    293851.000000     1.000000     2022.000000      5.000000     5.000000
#
#         curriculum  jobSupport
# count  1055.000000  959.000000
# mean      4.562085    4.497393
# std       0.663270    0.833625
# min       1.000000    1.000000
# 25%       4.000000    4.000000
# 50%       5.000000    5.000000
# 75%       5.000000    5.000000
# ...

# %%
app_academy_series=null_cleaned_df[null_cleaned_df["school"]=="app-academy"]
app_academy_series.describe()
# Out:
#                   id   anonymous  graduatingYear  overallScore     overall  \
# count     957.000000  957.000000      955.000000    957.000000  955.000000
# mean   253863.889237    0.310345     2018.606283      4.587983    4.680628
# std     16191.878629    0.462877        1.793876      0.558850    0.603616
# min    231519.000000    0.000000     2013.000000      1.000000    1.000000
# 25%    239840.000000    0.000000     2017.000000      4.300000    4.000000
# 50%    251097.000000    0.000000     2019.000000      4.700000    5.000000
# 75%    264307.000000    1.000000     2020.000000      5.000000    5.000000
# max    293770.000000    1.000000     2022.000000      5.000000    5.000000
#
#        curriculum  jobSupport
# count  952.000000  887.000000
# mean     4.574580    4.483653
# std      0.639322    0.780340
# min      1.000000    1.000000
# 25%      4.000000    4.000000
# 50%      5.000000    5.000000
# 75%      5.000000    5.000000
# max      5.000000    5.000000

# %%
print(list(null_cleaned_df.columns))

null_cleaned_df=null_cleaned_df[['id','anonymous','graduatingYear','tagline', 'program', 'overallScore', 'overall', 'curriculum', 'jobSupport', 'review_body', 'school', 'update_program', 'program_time', 'program_presence']]
null_cleaned_df
#scores_table=null_cleaned_df["id","graduatingYear",]
# Out:
# ['id', 'anonymous', 'graduatingYear', 'tagline', 'program', 'overallScore', 'overall', 'curriculum', 'jobSupport', 'review_body', 'school', 'update_program', 'program_time', 'program_presence']
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# ...

# %%
def school_id(s):
    if s=="ironhack":
        return 1
    elif s=="springboard":
        return 2
    elif  s=="app-academy":
        return 3



null_cleaned_df["school_id"]=null_cleaned_df["school"].apply(school_id)
null_cleaned_df
#null_cleaned_df["program_presence"] = null_cleaned_df["program"].apply(on_off_program)
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df["update_program"].unique()
# Out:
# array(['UX/UI', 'DATA', 'CYBER', 'WEBDEV'], dtype=object)

# %%
def course_id(s):
    if s=="UX/UI":
        return 1
    elif s=="DATA":
        return 2
    elif  s=="CYBER":
        return 3
    elif s=="WEBDEV":
        return 4



null_cleaned_df["course_id"]=null_cleaned_df["update_program"].apply(course_id)
null_cleaned_df
#null_cleaned_df["program_presence"] = null_cleaned_df["program"].apply(on_off_program)
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df["program_time"].unique()
# Out:
# array(['Full time', 'Part time'], dtype=object)

# %%
def course_time_id(s):
    if s=="Full time":
        return 1
    elif s=="Part time":
        return 2
    
null_cleaned_df["program_time_id"]=null_cleaned_df["program_time"].apply(course_time_id)
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df["program_presence"].unique()
# Out:
# array(['In Person', 'Online'], dtype=object)

# %%
def course_attendance_id(s):
    if s=="In Person":
        return 1
    elif s=="Online":
        return 2
    
null_cleaned_df["program_presence_id"]=null_cleaned_df["program_presence"].apply(course_attendance_id)
null_cleaned_df
# Out:
#           id  anonymous  graduatingYear  \
# 0     293764          0          2022.0
# 1     293752          1          2022.0
# 2     293725          1          2022.0
# 4     293621          0          2022.0
# 5     293620          1          2022.0
# ...      ...        ...             ...
# 3675  234894          0          2015.0
# 3676  234877          0          2015.0
# 3677  234838          0          2016.0
# 3678  242681          0          2016.0
# 3679  234178          0          2016.0
#
#                                                 tagline  \
# 0                                                 Great
# 1                                           Ux designer
# 2                                             Very good
# 4                         Fascinating and Underwhelming
# 5                                   Extremely Satisfied
# ...                                                 ...
# 3675              Excellent and comprehensive UX course
# ...

# %%
null_cleaned_df["program_presence_id"].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
null_cleaned_df.columns
# Out:
# Index(['id', 'anonymous', 'graduatingYear', 'tagline', 'program',
#        'overallScore', 'overall', 'curriculum', 'jobSupport', 'review_body',
#        'school', 'update_program', 'program_time', 'program_presence',
#        'school_id', 'course_id', 'program_time_id', 'program_presence_id'],
#       dtype='object')

# %%
comments_table=null_cleaned_df[['id', 'anonymous', 'graduatingYear',
       'overallScore', 'overall', 'curriculum', 'jobSupport', 'school_id','course_id', 'program_time_id','program_presence_id']]
comments_table
# Out:
#           id  anonymous  graduatingYear  overallScore  overall  curriculum  \
# 0     293764          0          2022.0           3.3      4.0         3.0
# 1     293752          1          2022.0           3.7      3.0         4.0
# 2     293725          1          2022.0           3.3      3.0         4.0
# 4     293621          0          2022.0           3.3      3.0         3.0
# 5     293620          1          2022.0           5.0      5.0         5.0
# ...      ...        ...             ...           ...      ...         ...
# 3675  234894          0          2015.0           5.0      5.0         5.0
# 3676  234877          0          2015.0           5.0      5.0         5.0
# 3677  234838          0          2016.0           3.7      4.0         4.0
# 3678  242681          0          2016.0           5.0      5.0         5.0
# 3679  234178          0          2016.0           4.7      5.0         5.0
#
# ...

# %%
courses_table=null_cleaned_df[['course_id','update_program']]
courses_table=courses_table.drop_duplicates()
courses_table
# Out:
#    course_id update_program
# 0          1          UX/UI
# 2          2           DATA
# 4          3          CYBER
# 5          4         WEBDEV

# %%
schools_table=null_cleaned_df[["school_id","school"]]
schools_table=schools_table.drop_duplicates()
schools_table
# Out:
#       school_id       school
# 0             1     ironhack
# 1162          3  app-academy
# 2322          2  springboard

# %%
null_cleaned_df.groupby(["school","update_program","program_time","program_presence"]).agg({"overallScore":"mean"})
# Out:
#                                                           overallScore
# school      update_program program_time program_presence
# app-academy WEBDEV         Full time    In Person             4.594325
#                                         Online                4.557317
# ironhack    CYBER          Full time    In Person             5.000000
#                            Part time    In Person             3.300000
#             DATA           Full time    In Person             4.421277
#                            Part time    In Person             4.072727
#             UX/UI          Full time    In Person             4.717375
#                            Part time    In Person             4.651515
#             WEBDEV         Full time    In Person             4.855420
#                            Part time    In Person             4.806349
# springboard CYBER          Full time    In Person             4.821429
# ...

# %%
null_cleaned_df.groupby(["school","update_program","program_time","program_presence"]).agg({"overallScore":"mean","overallScore":"count"})


#school_id	course_id	program_time_id	program_presence_id
#superstore.groupby(["Segment","State"]).agg({"Sales":"sum"})
# Out:
#                                                           overallScore
# school      update_program program_time program_presence
# app-academy WEBDEV         Full time    In Person                  793
#                                         Online                     164
# ironhack    CYBER          Full time    In Person                    1
#                            Part time    In Person                    1
#             DATA           Full time    In Person                   47
#                            Part time    In Person                   11
#             UX/UI          Full time    In Person                  259
#                            Part time    In Person                   33
#             WEBDEV         Full time    In Person                  572
#                            Part time    In Person                  126
# springboard CYBER          Full time    In Person                   14
# ...

# %%
course_school_options=null_cleaned_df.groupby(["school_id","course_id","program_time_id","program_presence_id"]).agg({"overallScore":"mean"})
course_school_options.reset_index(inplace=True)

# %%
course_school_relation=course_school_options[["school_id","course_id"]]
course_school_relation
# Out:
#     school_id  course_id
# 0           1          1
# 1           1          1
# 2           1          2
# 3           1          2
# 4           1          3
# 5           1          3
# 6           1          4
# 7           1          4
# 8           2          1
# 9           2          2
# 10          2          3
# 11          2          4
# 12          3          4
# 13          3          4

# %%
time_table=null_cleaned_df[["program_time_id","program_time"]]
time_table=time_table.drop_duplicates()
time_table
# Out:
#    program_time_id program_time
# 0                1    Full time
# 2                2    Part time

# %%
presence_table=null_cleaned_df[["program_presence_id","program_presence"]]
presence_table=presence_table.drop_duplicates()
presence_table
# Out:
#       program_presence_id program_presence
# 0                       1        In Person
# 1162                    2           Online

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Newchapter1!",
                               db="clean_lake"))

# %%
comments_table.to_sql('comments_table', con = engine, if_exists = 'append', chunksize = 1000)
courses_table.to_sql('courses_table', con = engine, if_exists = 'append', chunksize = 1000)
schools_table.to_sql('schools_table', con = engine, if_exists = 'append', chunksize = 1000)
presence_table.to_sql('presence_table', con = engine, if_exists = 'append', chunksize = 1000)
time_table.to_sql('time_table', con = engine, if_exists = 'append', chunksize = 1000)
# Out:
# 2

# %%
null_cleaned_df.groupby(["update_program"]).agg({"overallScore":"mean"})
# Out:
#                 overallScore
# update_program
# CYBER               4.737500
# DATA                4.528407
# UX/UI               4.649856
# WEBDEV              4.699024

# %%
null_cleaned_df.groupby(["program_time"]).agg({"overallScore":"mean"})
# Out:
#               overallScore
# program_time
# Full time         4.650207
# Part time         4.720468

# %%
null_cleaned_df.groupby(["program_presence"]).agg({"overallScore":"mean"})
# Out:
#                   overallScore
# program_presence
# In Person             4.659607
# Online                4.557317
